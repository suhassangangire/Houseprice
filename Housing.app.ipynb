# %%
import pandas as pd

# %%
Data_Set = pd.read_csv('../Desktop/Python/DATASET/trHouse price train data.csv')

# %%
Data_Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
Data_Set.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
Data_Set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
Data_Set.shape
# Out:
# (1460, 81)

# %%
Data_Set.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# SalePrice        1460
# Length: 81, dtype: int64

# %%
Data_Set.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
Data_Set.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(Data_Set.isnull())
plt.show()

# %%
Data_Set.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
Data_Set.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
  Data_Set.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
Data_Set['SaleCondition'] = Data_Set.SaleCondition

# %%
Data_Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
Data_Set['SaleCondition'] =  Data_Set['SaleCondition']

# %%
Data_Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
Data_Set.drop( [ 'Alley'] , axis= 1 )
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
Data_Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
Data_Set.drop (['Alley'] , axis= 1 , inplace= True)

# %%
Data_Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
Data_Set.drop(['MiscVal', 'PoolArea' , 'ScreenPorch' , '3SsnPorch'] , axis= 1 , inplace= False)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch PoolQC  \
# ...

# %%
Data_Set.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0    AllPub    Inside  ...        0    NaN   NaN         NaN       0      2
# 1    AllPub       FR2  ...        0    NaN   NaN         NaN       0      5
# 2    AllPub    Inside  ...        0    NaN   NaN         NaN       0      9
# 3    AllPub    Corner  ...        0    NaN   NaN         NaN       0      2
# 4    AllPub       FR2  ...        0    NaN   NaN         NaN       0     12
#
#    YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
Data_Set.PoolQC =  0

# %%
Data_Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
Data_Set.PoolQC =  0

# %%
Data_Set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
Data_Set.PoolQC == 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1455    True
# 1456    True
# 1457    True
# 1458    True
# 1459    True
# Name: PoolQC, Length: 1460, dtype: bool

# %%
Data_Set[Data_Set.PoolQC ==  0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
len(Data_Set[Data_Set.PoolQC == 0])
# Out:
# 1460

# %%
Data_Set.LotFrontage = Data_Set.dtypes

# %%
Data_Set.head()
# Out:
#    Id  MSSubClass MSZoning LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         NaN     8450   Pave      Reg         Lvl
# 1   2          20       RL         NaN     9600   Pave      Reg         Lvl
# 2   3          60       RL         NaN    11250   Pave      IR1         Lvl
# 3   4          70       RL         NaN     9550   Pave      IR1         Lvl
# 4   5          60       RL         NaN    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0    AllPub    Inside  ...        0      0   NaN         NaN       0      2
# 1    AllPub       FR2  ...        0      0   NaN         NaN       0      5
# 2    AllPub    Inside  ...        0      0   NaN         NaN       0      9
# 3    AllPub    Corner  ...        0      0   NaN         NaN       0      2
# 4    AllPub       FR2  ...        0      0   NaN         NaN       0     12
#
#    YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
Data_Set.MSSubClass == 'Class'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: MSSubClass, Length: 1460, dtype: bool

# %%
Df1 = Data_Set[Data_Set.MSSubClass == 'Class']

# %%
Df1
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %%
Data_Set.groupby
# Out:
# <bound method DataFrame.groupby of         Id  MSSubClass MSZoning LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         NaN     8450   Pave      Reg
# 1        2          20       RL         NaN     9600   Pave      Reg
# 2        3          60       RL         NaN    11250   Pave      IR1
# 3        4          70       RL         NaN     9550   Pave      IR1
# 4        5          60       RL         NaN    14260   Pave      IR1
# ...    ...         ...      ...         ...      ...    ...      ...
# 1455  1456          60       RL         NaN     7917   Pave      Reg
# 1456  1457          20       RL         NaN    13175   Pave      Reg
# 1457  1458          70       RL         NaN     9042   Pave      Reg
# 1458  1459          20       RL         NaN     9717   Pave      Reg
# 1459  1460          20       RL         NaN     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
Data_Set.groupby('LotConfig')

# %%
Data_Set.groupby('LotConfig').SalePrice.max()
# Out:
# LotConfig
# Corner     755000
# CulDSac    625000
# FR2        394617
# FR3        315000
# Inside     611657
# Name: SalePrice, dtype: int64

# %%
Data_Set.groupby('LotConfig').SalePrice.min()
# Out:
# LotConfig
# Corner      52500
# CulDSac     84000
# FR2         81000
# FR3        128000
# Inside      34900
# Name: SalePrice, dtype: int64

# %%
Df1.groupby('LotConfig').SalePrice.max()
# Out:
# Series([], Name: SalePrice, dtype: int64)

# %%
Data_Set.groupby('LotConfig').SalePrice.mean()
# Out:
# LotConfig
# Corner     181623.425856
# CulDSac    223854.617021
# FR2        177934.574468
# FR3        208475.000000
# Inside     176938.047529
# Name: SalePrice, dtype: float64

# %%
Data_Set.groupby('SaleCondition').mean()
# Out:
#                        Id  MSSubClass       LotArea  OverallQual  OverallCond  \
# SaleCondition
# Abnorml        741.336634   57.673267   9450.801980     5.574257     5.386139
# AdjLand        450.250000   70.000000   8002.500000     5.000000     4.750000
# Alloca         688.750000   70.833333  11499.583333     5.416667     5.166667
# Family         747.900000   57.250000   9604.050000     5.800000     5.350000
# Normal         733.630217   57.378965  10543.478297     6.006678     5.659432
# Partial        701.936000   49.840000  11254.920000     7.560000     5.024000
#
#                  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# SaleCondition
# Abnorml        1959.059406   1974.574257   74.049505  402.108911   75.148515
# AdjLand        1945.000000   1969.000000   62.500000  314.250000    0.000000
# Alloca         1967.916667   1980.166667   82.727273  550.666667    0.000000
# Family         1962.100000   1976.450000   88.500000  446.600000   35.700000
# ...

# %%
Data_Set.groupby('SaleCondition').max()
# Out:
# C:\Users\suhas\AppData\Local\Temp/ipykernel_29904/4000887451.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   Data_Set.groupby('SaleCondition').max()
#                  Id  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# SaleCondition
# Abnorml        1454         190       RM          NaN    28698   Pave
# AdjLand         955          90       RL          NaN     9400   Pave
# Alloca         1424          90       RM          NaN    32668   Pave
# Family         1405         160       RM          NaN    14572   Pave
# Normal         1460         190       RM          NaN   215245   Pave
# Partial        1452         190       RM          NaN    63887   Pave
#
#               LotShape LandContour Utilities LotConfig  ... EnclosedPorch  \
# SaleCondition                                           ...
# ...

# %%
Data_Set.groupby('SaleCondition').min()
# Out:
# C:\Users\suhas\AppData\Local\Temp/ipykernel_29904/494732464.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   Data_Set.groupby('SaleCondition').min()
#                 Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# SaleCondition
# Abnorml          4          20  C (all)          NaN     1533   Pave      IR1
# AdjLand         40          50       RL          NaN     6040   Pave      IR1
# Alloca         103          20  C (all)          NaN     5925   Grvl      IR1
# Family         138          20       RL          NaN     1680   Pave      IR1
# Normal           1          20  C (all)          NaN     1300   Grvl      IR1
# Partial         12          20       FV          NaN     3000   Pave      IR1
#
#               LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch  \
# ...

# %%
Data_Set.groupby('SaleCondition').mean()
# Out:
#                        Id  MSSubClass       LotArea  OverallQual  OverallCond  \
# SaleCondition
# Abnorml        741.336634   57.673267   9450.801980     5.574257     5.386139
# AdjLand        450.250000   70.000000   8002.500000     5.000000     4.750000
# Alloca         688.750000   70.833333  11499.583333     5.416667     5.166667
# Family         747.900000   57.250000   9604.050000     5.800000     5.350000
# Normal         733.630217   57.378965  10543.478297     6.006678     5.659432
# Partial        701.936000   49.840000  11254.920000     7.560000     5.024000
#
#                  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# SaleCondition
# Abnorml        1959.059406   1974.574257   74.049505  402.108911   75.148515
# AdjLand        1945.000000   1969.000000   62.500000  314.250000    0.000000
# Alloca         1967.916667   1980.166667   82.727273  550.666667    0.000000
# Family         1962.100000   1976.450000   88.500000  446.600000   35.700000
# ...

# %%
Data_Set.groupby('LotConfig').SaleCondition.max()
# Out:
# LotConfig
# Corner     Partial
# CulDSac    Partial
# FR2        Partial
# FR3         Normal
# Inside     Partial
# Name: SaleCondition, dtype: object

# %%
Data_Set.groupby('LotConfig').SaleCondition.max().sort_values(ascending = False)
# Out:
# LotConfig
# Corner     Partial
# CulDSac    Partial
# FR2        Partial
# Inside     Partial
# FR3         Normal
# Name: SaleCondition, dtype: object

# %%
Data_Set.groupby('SalePrice').SaleCondition.max()
# Out:
# SalePrice
# 34900     Abnorml
# 35311     Abnorml
# 37900     Abnorml
# 39300      Normal
# 40000      Normal
#            ...
# 582933    Partial
# 611657    Partial
# 625000     Normal
# 745000    Abnorml
# 755000     Normal
# Name: SaleCondition, Length: 663, dtype: object

# %%
Data_Set.groupby('SalePrice').SaleCondition.min()
# Out:
# SalePrice
# 34900     Abnorml
# 35311     Abnorml
# 37900     Abnorml
# 39300      Normal
# 40000      Normal
#            ...
# 582933    Partial
# 611657    Partial
# 625000     Normal
# 745000    Abnorml
# 755000     Normal
# Name: SaleCondition, Length: 663, dtype: object

# %%
Data_Set.groupby('SalePrice').SaleCondition.max().sort_values(ascending = True)
# Out:
# SalePrice
# 34900     Abnorml
# 98600     Abnorml
# 116050    Abnorml
# 97500     Abnorml
# 159434    Abnorml
#            ...
# 240000    Partial
# 244600    Partial
# 246578    Partial
# 248900    Partial
# 179540    Partial
# Name: SaleCondition, Length: 663, dtype: object

# %%
Data_Set.groupby('SalePrice').SaleCondition.max().sort_values(ascending = False)
# Out:
# SalePrice
# 179540    Partial
# 248900    Partial
# 181134    Partial
# 244600    Partial
# 240000    Partial
#            ...
# 257000    Abnorml
# 92000     Abnorml
# 258000    Abnorml
# 144152    Abnorml
# 34900     Abnorml
# Name: SaleCondition, Length: 663, dtype: object

# %%
Data_Set.groupby('SalePrice').SaleCondition.max().sort_values(ascending = False)
# Out:
# SalePrice
# 179540    Partial
# 248900    Partial
# 181134    Partial
# 244600    Partial
# 240000    Partial
#            ...
# 257000    Abnorml
# 92000     Abnorml
# 258000    Abnorml
# 144152    Abnorml
# 34900     Abnorml
# Name: SaleCondition, Length: 663, dtype: object

# %%
Data_Set[Data_Set.SalePrice < 200000]
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street LotShape  \
# 1        2          20       RL         NaN     9600   Pave      Reg
# 3        4          70       RL         NaN     9550   Pave      IR1
# 5        6          50       RL         NaN    14115   Pave      IR1
# 8        9          50       RM         NaN     6120   Pave      Reg
# 9       10         190       RL         NaN     7420   Pave      Reg
# ...    ...         ...      ...         ...      ...    ...      ...
# 1453  1454          20       RL         NaN    17217   Pave      Reg
# 1454  1455          20       FV         NaN     7500   Pave      Reg
# 1455  1456          60       RL         NaN     7917   Pave      Reg
# 1458  1459          20       RL         NaN     9717   Pave      Reg
# 1459  1460          20       RL         NaN     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
Data_Set.groupby('YrSold').max()
# Out:
# C:\Users\suhas\AppData\Local\Temp/ipykernel_29904/3952997585.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   Data_Set.groupby('YrSold').max()
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# YrSold
# 2006    1454         190       RM          NaN    70761   Pave      Reg
# 2007    1456         190       RM          NaN   159000   Pave      Reg
# 2008    1460         190       RM          NaN   164660   Pave      Reg
# 2009    1455         190       RM          NaN   215245   Pave      Reg
# 2010    1459         190       RM          NaN    57200   Pave      Reg
#
#        LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch  \
# YrSold                                  ...
# 2006           Lvl    AllPub    Inside  ...           552       290
# ...

# %%
Data_Set.groupby('YrSold').min()
# Out:
# C:\Users\suhas\AppData\Local\Temp/ipykernel_29904/2131539472.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   Data_Set.groupby('YrSold').min()
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# YrSold
# 2006     4          20  C (all)          NaN     1533   Pave      IR1
# 2007     2          20  C (all)          NaN     1890   Grvl      IR1
# 2008     1          20  C (all)          NaN     1680   Grvl      IR1
# 2009     6          20  C (all)          NaN     1300   Pave      IR1
# 2010    17          20  C (all)          NaN     1491   Grvl      IR1
#
#        LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch  \
# YrSold                                  ...
# 2006           Bnk    AllPub    Corner  ...             0         0
# ...

# %%
Data_Set.groupby('YrSold').mean()
# Out:
#                 Id  MSSubClass       LotArea  OverallQual  OverallCond  \
# YrSold
# 2006    740.191083   59.888535  10489.458599     6.130573     5.420382
# 2007    710.753799   54.316109  10863.686930     6.133739     5.583587
# 2008    730.213816   59.029605  10587.687500     6.111842     5.759868
# 2009    750.943787   54.674556  10294.248521     6.076923     5.514793
# 2010    711.245714   56.971429  10220.645714     6.000000     5.634286
#
#           YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  \
# YrSold                                                                 ...
# 2006    1972.117834   1982.585987   93.869010  444.754777   39.898089  ...
# 2007    1972.279635   1986.018237  117.428135  411.656535   43.905775  ...
# 2008    1968.907895   1984.796053  107.156146  472.417763   50.437500  ...
# 2009    1971.757396   1985.866864  102.445104  443.579882   42.668639  ...
# 2010    1970.994286   1984.977143   91.913793  451.891429   64.194286  ...
#
# ...

# %%
Data_Set[Data_Set.SalePrice < 200000].YrSold.value_counts()
# Out:
# 2009    240
# 2007    226
# 2008    220
# 2006    217
# 2010    122
# Name: YrSold, dtype: int64

# %%
Data_Set[Data_Set.SalePrice < 200000].LotConfig.value_counts()
# Out:
# Inside     757
# Corner     183
# CulDSac     47
# FR2         36
# FR3          2
# Name: LotConfig, dtype: int64

# %%
Data_Set[Data_Set.SalePrice < 200000].LotConfig.count()
# Out:
# 1025

# %%
Data_Set[Data_Set.SalePrice >20000 ].LotConfig.value_counts()
# Out:
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: LotConfig, dtype: int64
